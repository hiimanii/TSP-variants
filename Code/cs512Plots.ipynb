# %%
import pickle

with open('data_aco.pkl', 'rb') as f:
    data_aco = pickle.load(f)
    
with open('ants.pkl', 'rb') as f:
    ants = pickle.load(f)
    
with open('data_bho.pkl', 'rb') as f:
    data_bho = pickle.load(f)
    
with open('num_candidates_bho.pkl', 'rb') as f:
    num_candidates_bho = pickle.load(f)
    
with open('stars.pkl', 'rb') as f:
    stars = pickle.load(f)
    
with open('data_pso.pkl', 'rb') as f:
    data_pso = pickle.load(f)
    
with open('num_candidates_pso.pkl', 'rb') as f:
    num_candidates_pso = pickle.load(f)
    
with open('particles.pkl', 'rb') as f:
    particles = pickle.load(f)

# %%
import matplotlib.pyplot as plt

plt.scatter(ants, data_aco)
plt.show()

# %%
plt.scatter(stars, data_bho)
plt.show()

# %%
plt.scatter(stars, num_candidates_bho)
plt.show()

# %%
plt.scatter(particles, data_pso)
plt.show()

# %%
plt.scatter(particles, num_candidates_pso)
plt.show()

# %%
plt.boxplot(data_aco)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1959ce7a160>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1959ce7a820>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1959ce55dc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1959ce7aee0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1959ce8f280>],
#  'means': []}

# %%
plt.boxplot(data_bho)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1959ccaa9d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1959ccaa190>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1959ccaaa60>],
#  'medians': [<matplotlib.lines.Line2D at 0x1959cbd99a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1959cbd98b0>],
#  'means': []}

# %%
plt.boxplot(data_pso)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1959cb1ae50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1959cb1ae80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1959cb1a880>],
#  'medians': [<matplotlib.lines.Line2D at 0x1959c4472b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1959c447220>],
#  'means': []}
